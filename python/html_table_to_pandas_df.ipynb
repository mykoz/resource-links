# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import re
import pandas as pd

# %%
url = 'http://www.boxofficemojo.com/genres/chart/?id-foreign.htm'
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page)
#, "lxml", markup_type=markup_type)

# %%
tables = soup.find_all('table')

# %%
d={}
for row in tables[2].find_all('tr')[2:]:
    temp=[]
    for cell in row.find_all('td'):
        temp.append(cell.text)
    d[temp[1]] = temp[2:]

# %%
d.items()[1]
# Out:
# (u'135', [u'The Blind Side', u'$256.0'])

# %%
import pandas as pd
test = pd.DataFrame.from_dict(d, orient='index')

# %%
test.head()
# Out:
#                          0       1
# 131  Passion of the Christ  $370.8
# 135         The Blind Side  $256.0
# 138           The Avengers  $623.4
# 24                     Ted  $218.8
# 25        Dead Man's Chest  $423.3
